# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

unlabelled= pd.read_csv('/kaggle/input/jigsaw-2m-reddit-unlabelled/reddit-removal-log.csv')

# %%
df_train= pd.read_csv('/kaggle/input/jigsaw-agile-community-rules/train.csv')

# %%
legal= unlabelled.query('subreddit in @["legaladvice","relationships","personalfinance"]')
legal.rule= 'No Legal Advice: Do not offer or request legal advice.'
